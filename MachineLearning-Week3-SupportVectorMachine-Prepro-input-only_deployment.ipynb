# %%
import pickle
filename="sc.pkl"
loaded_sc=pickle.load(open(filename,'rb'))

# %%
preinput=loaded_sc.transform([[19,27.9,0,0,1]])
preinput
# Out:
# array([[-1.42318024, -0.45428577, -0.9000987 , -1.03037566,  1.91833261]])

# %%
import pickle
filename="Finalised_model_SVM_Prepro_input.sav"
loaded_model=pickle.load(open(filename,'rb'))
result=loaded_model.predict(preinput)
result
# Out:
# array([16035.51723447])
