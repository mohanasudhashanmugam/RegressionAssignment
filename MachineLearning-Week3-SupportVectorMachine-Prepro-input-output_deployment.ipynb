# %%
import pickle
filename="sc.pkl"
loaded_sc=pickle.load(open(filename,'rb'))

# %%
preinput=loaded_sc.transform([[19,27.9,0,0,1]])
preinput
# Out:
# array([[-1.44355711, -0.44852533, -0.89339893, -0.98726063,  1.89426379]])

# %%
import pickle
filename="Finalised_model_SVM_Prepro_input_output.sav"
loaded_model=pickle.load(open(filename,'rb'))
result=loaded_model.predict(preinput)
result
# Out:
# array([0.71725073])

# %%
import pickle
loaded_scy=pickle.load(open("scy.pkl",'rb'))
preoutput=loaded_scy.inverse_transform(result)
preoutput
# Out:
# array([22113.12380379])
